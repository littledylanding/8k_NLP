# %%
from sumy.parsers.plaintext import PlaintextParser
from sumy.nlp.tokenizers import Tokenizer
from sumy.summarizers.lex_rank import LexRankSummarizer
import pandas as pd

# %%
df = pd.read_csv('train_set.csv')
# df = df.iloc[40:60,:]

# %% [markdown]
# ## Sumy

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\lisbo\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# True

# %%
def sumy_summarize(text):
    parser = PlaintextParser.from_string(text, Tokenizer("english"))
    summarizer = LexRankSummarizer()
    summary = summarizer(parser.document, 5)  # Summarize to 5 sentences
    return ' '.join([str(sentence) for sentence in summary])

df['summary_sumy'] = df['Content'].apply(sumy_summarize)

# %%
df
# Out:
#   Ticker      Accession Number      Date  \
# 0   LANC  0000057515-22-000012  20220817
# 1   LANC  0000057515-22-000024  20221110
# 2   LANC  0000057515-20-000023  20200827
# 3   LANC  0000057515-21-000020  20211103
# 4   LANC  0000057515-20-000014  20200505
#
#                                              Content  \
# 0  Item8.01 Other EventsOn August 17, 2022, Lanca...
# 1  Item5.07 Submission of Matters to a Vote of Se...
# 2  Item2.02 Results of Operations and Financial C...
# 3  Item2.02 Results of Operations and Financial C...
# 4  Item2.02 Results of Operations and Financial C...
#
#                                         summary_sumy
# 0  Item8.01 Other EventsOn August 17, 2022, Lanca...
# 1  Item5.07 Submission of Matters to a Vote of Se...
# 2  Item2.02 Results of Operations and Financial C...
# 3  Item2.02 Results of Operations and Financial C...
# 4  Item2.02 Results of Operations and Financial C...

# %% [markdown]
# ## Bert

# %%
from summarizer import Summarizer

bert_model = Summarizer()

def bert_summarize(text):
    return bert_model(text, num_sentences=5)

df['summary_bert'] = df['Content'].apply(bert_summarize)
# Out:
# Downloading:   0%|          | 0.00/1.34G [00:00<?, ?B/s]
# Some weights of the model checkpoint at bert-large-uncased were not used when initializing BertModel: ['cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.bias', 'cls.seq_relationship.weight']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# C:\Users\lisbo\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\lisbo\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\lisbo\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\lisbo\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\lisbo\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\lisbo\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\lisbo\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\lisbo\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\lisbo\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\lisbo\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %% [markdown]
# ## Bart

# %%
from transformers import BartForConditionalGeneration, BartTokenizer

bart_model_name = 'facebook/bart-large-cnn'
bart_model = BartForConditionalGeneration.from_pretrained(bart_model_name)
bart_tokenizer = BartTokenizer.from_pretrained(bart_model_name)

def bart_summarize(text):
    inputs = bart_tokenizer([text], max_length=1024, return_tensors='pt', truncation=True)
    summary_ids = bart_model.generate(inputs.input_ids, num_beams=4, min_length=30, max_length=250, early_stopping=True)
    return bart_tokenizer.decode(summary_ids[0], skip_special_tokens=True)

df['summary_bart'] = df['Content'].apply(bart_summarize)

# %%
df.head()
# Out:
#     Unnamed: 0 Ticker      Accession Number        Date  \
# 0            0    AAP  0001158449-19-000025  2019-01-29
# 1            1   AMBC  0000874501-20-000012  2020-01-23
# 2            2   AMBC  0000874501-22-000149  2022-10-13
# 3            3   APPS  0001628280-22-014669  2022-05-17
# 4            4   ATEN  0001580808-18-000021  2018-04-06
# 5            5   ATEN  0001628280-18-008978  2018-07-02
# 6            6     AX  0001299709-18-000113  2018-09-12
# 7            7     AX  0001299709-21-000024  2021-02-24
# 8            8    AZZ  0000008947-18-000030  2018-03-29
# 9            9   CLDT  0001476045-20-000043  2020-03-26
# 10          10    CMP  0001227654-21-000185  2021-08-05
# 11          11    CPE  0000928022-20-000055  2020-04-17
# 12          12    CRC  0001609253-20-000114  2020-07-16
# 13          13    CRC  0001609253-20-000116  2020-07-17
# 14          14    CRC  0001609253-20-000118  2020-07-24
# 15          15    CRC  0001609253-20-000133  2020-10-19
# 16          16    CRC  0001609253-20-000193  2020-11-02
# 17          17   CTRE  0001628280-22-013475  2022-05-10
# 28  Item3.01 Notice of Delisting or Failure to Sat...               0.123539
# 29  Item1.01. Entry into a Material Definitive Agr...                    NaN
# 30  Item3.01. Notice of Delisting or Failure to Sa...               0.097236
# 31  Item3.01 Notice of Delisting or Failure to Sat...               0.048181
# 32  Item3.01 Notice of Delisting or Failure to Sat...              -0.023433
# 33  Item4.02. Non-Reliance on Previously Issued Fi...               0.014774
# 34  Item3.01. Notice of Delisting or Failure to Sa...              -0.014721
# 35  Item2.02 Results of Operations and Financial C...              -0.020199
# 36  Item5.01.Changes in Control of Registrant.Acco...               0.033788
# 37  Item3.01 Notice of Delisting or Failure to Sat...               0.015399
# 38  Item2.02 Results of Operations and Financial C...               0.042123
# 39  Item3.01 Notice of Delisting or Failure to Sat...              -0.330686
# 40  Item3.01. otice of Delisting or Failure to Sat...              -0.355064
# 41  Item4.02. Non-Reliance on Previously Issued Fi...               0.014392
# 42  Item2.02 Results of Operations and Financial C...              -0.157954
#
#                                          summary_bart
# 0   On January 29, 2019, Advance Auto Parts, Inc. ...
# 1   Ambac Financial Group, Inc. (the “Company”), a...
# 2   Ambac Assurance Corporation (“AAC”) entered in...
# 3   Digital Turbine, Inc. issued a press release r...
# 4   A10 Networks, Inc. received a notice from the ...
# 5   A10 Networks announced today that the Audit Co...
# 6   BofI Holding, Inc. (the “Company”) provided wr...
# 7   Axos Financial, Inc. (the “Company”) caused no...
# 8   AZZ Inc. issued a press release announcing its...
# 9   Effective March 27, 2020, Jeffrey H. Fisher, C...
# 10  Compass Minerals International, Inc. (the "Com...
# 11  The Company was notified by the New York Stock...
# 12  California Resources Corporation (the “Company...
# 13  On July 15, 2020, California Resources Corpora...
# 14  California Resources Corporation and certain o...
# 15  On July 15, 2020, California Resources Corpora...
# 16  The Company entered into a Credit Agreement, d...
# 17  On May 10, 2022, CareTrust REIT, Inc. (the “Co...
# 18  CVR Energy, Inc. (the “Company”) deeply regret...
# 19  On March 1, 2019, Ellington notified the New Y...
# 20  Thomas C. Roberts retired from his position as...
# 21  Hanmi Financial Corporation received a letter ...
# 22  On May 10, 2018, Kulicke and Soffa Industries,...
# 23  Kulicke and Soffa Industries, Inc. received a ...
# 24  On March 5, 2018 Ligand Pharmaceuticals Inc. a...
# 25  FMC Corporation (“FMC”) completed its previous...
# 26  On December 13, 2019, Moog Inc. announced that...
# 27  On December 21, 2017, Mercury Systems, Inc. (“...
# 28  MaxLinear, Inc., (the “Company”) acting pursua...
# 29  On July 16, 2021, N-able, Inc. (the “Company”)...
# 30  On February 14, 2022, Northern Oil and Gas, In...
# 31   NV5 Global, Inc. received notification from N...
# 32  Par Pacific Holdings, Inc. (the “Company”), ac...
# 33  In connection with the integration of the deal...
# 34  ServisFirst Bancshares, Inc. (the “Company”) a...
# 35  The Simply Good Foods Company, a Delaware corp...
# 36  The Company is filing the aforementioned discl...
# 37  Supernus Pharmaceuticals, Inc. (the “Company”)...
# 38  Hostess Brands, Inc. (the “Company”) has publi...
# 39  United Natural Foods, Inc. expects to voluntar...
# 40  The average closing price of the Company's com...
# 41  On August 4, 2020, the Audit Committee of the ...
# 42  Whitestone REIT announced its financial result...

# %%
df.to_csv("summary.csv")
